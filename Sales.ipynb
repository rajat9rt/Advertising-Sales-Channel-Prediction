# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Sales.csv")

# %%
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.tail()
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
df.shape
# Out:
# (200, 5)

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# TV            float64
# radio         float64
# newspaper     float64
# sales         float64
# dtype: object

# %% [raw]
# # We observe that all the colums have float value.

# %%
df["sales"]=df["sales"].astype(float)

# %%
df.sales.dtype
# Out:
# dtype('float64')

# %%
np.mean(df["sales"])
# Out:
# 14.022500000000003

# %%
df.iloc[199,:]
# Out:
# Unnamed: 0    200.0
# TV            232.1
# radio           8.6
# newspaper       8.7
# sales          13.4
# Name: 199, dtype: float64

# %%
df["sales"]=df["sales"].fillna(np.mean(df["sales"]))

# %%
df.iloc[199,:]
# Out:
# Unnamed: 0    200.0
# TV            232.1
# radio           8.6
# newspaper       8.7
# sales          13.4
# Name: 199, dtype: float64

# %%
len(df["sales"].dropna())
# Out:
# 200

# %%
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df["TV"].dropna()
# Out:
# 0      230.1
# 1       44.5
# 2       17.2
# 3      151.5
# 4      180.8
#        ...
# 195     38.2
# 196     94.2
# 197    177.0
# 198    283.6
# 199    232.1
# Name: TV, Length: 200, dtype: float64

# %%
df.dropna()
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# # Making DataFrame for the Nominal Data

# %%
df_visulization_nominal=df[['TV','radio','newspaper','sales']].copy()

# %%
df_visulization_nominal.columns
# Out:
# Index(['TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
id(df)
# Out:
# 2850665719168

# %%
id(df_visulization_nominal)
# Out:
# 2850703494208

# %% [markdown]
# # Visulization of the Data:

# %%
import seaborn as sns

# %%
ax=sns.countplot(x="sales",data=df_visulization_nominal)
print(df_visulization_nominal["sales"].value_counts())
# Out:
# 9.7     5
# 11.7    4
# 12.9    4
# 15.9    4
# 20.7    3
#        ..
# 17.0    1
# 18.3    1
# 22.3    1
# 14.0    1
# 25.5    1
# Name: sales, Length: 121, dtype: int64

# %%
ax=sns.lineplot(x=df_visulization_nominal["sales"],y=df_visulization_nominal["TV"],data=df_visulization_nominal)
print(ax.value_counts())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\RAJATS~1\AppData\Local\Temp/ipykernel_12760/1839793268.py in <module>
#       1 ax=sns.lineplot(x=df_visulization_nominal["sales"],y=df_visulization_nominal["TV"],data=df_visulization_nominal)
# ----> 2 print(ax.value_counts())
#
# AttributeError: 'AxesSubplot' object has no attribute 'value_counts'

# %%
sns.lineplot(x=df["sales"],y=df["TV"],data=df_visulization_nominal)
# Out:
# <AxesSubplot:xlabel='sales', ylabel='TV'>

# %%
sns.scatterplot(x=df["sales"],y=df["TV"],data=df)
# Out:
# <AxesSubplot:xlabel='sales', ylabel='TV'>

# %%
# In both graph identify that as the TV distribution chanel is directly dependent on salse uniit.

# %%
sns.scatterplot(x=df["sales"],y=df["radio"],data=df)
# Out:
# <AxesSubplot:xlabel='sales', ylabel='radio'>

# %%
#In this graph identify that as the radio chanel is not-directly dependent on salse uniit.

# %%
sns.scatterplot(x=df["sales"],y=df["newspaper"],data=df)
# Out:
# <AxesSubplot:xlabel='sales', ylabel='newspaper'>

# %%
#In this graph identify that as the newspaper chanel is not-directly dependent on salse uniit.

# %%
# When we compare all the fig & Graph TV distribution is best among them.

# %%
import matplotlib.pyplot as plt
sns.pairplot(df)
plt.savefig('pairplot.png')
plt.show()

# %%
df.corr()
# Out:
#             Unnamed: 0        TV     radio  newspaper     sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
df.corr()["sales"].sort_values()
# Out:
# Unnamed: 0   -0.051616
# newspaper     0.228299
# radio         0.576223
# TV            0.782224
# sales         1.000000
# Name: sales, dtype: float64

# %%
# We can see that correlation of TV higher than other Chanel.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, linewidths=0.5, linecolor="black", fmt = '.2f')
# Out:
# <AxesSubplot:>

# %%
round(df.describe()[1:].transpose(),2)
# Out:
#               mean    std  min    25%     50%     75%    max
# Unnamed: 0  100.50  57.88  1.0  50.75  100.50  150.25  200.0
# TV          147.04  85.85  0.7  74.38  149.75  218.82  296.4
# radio        23.26  14.85  0.0   9.98   22.90   36.52   49.6
# newspaper    30.55  21.78  0.3  12.75   25.75   45.10  114.0
# sales        14.02   5.22  1.6  10.38   12.90   17.40   27.0

# %%
round(df.describe(),2)
# Out:
#        Unnamed: 0      TV   radio  newspaper   sales
# count      200.00  200.00  200.00     200.00  200.00
# mean       100.50  147.04   23.26      30.55   14.02
# std         57.88   85.85   14.85      21.78    5.22
# min          1.00    0.70    0.00       0.30    1.60
# 25%         50.75   74.38    9.98      12.75   10.38
# 50%        100.50  149.75   22.90      25.75   12.90
# 75%        150.25  218.82   36.52      45.10   17.40
# max        200.00  296.40   49.60     114.00   27.00

# %%
# All the columns of the datasets is postively correalted with the target column.

#1.TV has 78 percent correlation with the target column which can be considered as a good bond.
#2.Radio has 58 percent correlation with the target column which can be considered as a good bond.
#3.Newspaper has 23 percent correlation with the target column which can be considered as a week bond.

# Max correlation: TV
# Min Correlation: Newspaper.

# %% [markdown]
# # Discriptive Statistics

# %%
#Describing Datasets

# %%
round(df.describe()[1:].transpose(),2)
# Out:
#               mean    std  min    25%     50%     75%    max
# Unnamed: 0  100.50  57.88  1.0  50.75  100.50  150.25  200.0
# TV          147.04  85.85  0.7  74.38  149.75  218.82  296.4
# radio        23.26  14.85  0.0   9.98   22.90   36.52   49.6
# newspaper    30.55  21.78  0.3  12.75   25.75   45.10  114.0
# sales        14.02   5.22  1.6  10.38   12.90   17.40   27.0

# %%
round(df.describe(),2)
# Out:
#        Unnamed: 0      TV   radio  newspaper   sales
# count      200.00  200.00  200.00     200.00  200.00
# mean       100.50  147.04   23.26      30.55   14.02
# std         57.88   85.85   14.85      21.78    5.22
# min          1.00    0.70    0.00       0.30    1.60
# 25%         50.75   74.38    9.98      12.75   10.38
# 50%        100.50  149.75   22.90      25.75   12.90
# 75%        150.25  218.82   36.52      45.10   17.40
# max        200.00  296.40   49.60     114.00   27.00

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(round(df.describe()[1:].transpose(),2),annot=True, linewidths=0.5, linecolor="black", fmt = 'f')
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variable Summary")
plt.savefig('heatmap.png')
plt.show()

# %%
# From the above plotting we are determining mean, standard deviation, minimum and maximum of each column. It helps us further in Data Cleaning

# Total Numbers of rows and columns in datasets.

#1. 200 rows
#2. 5 columns

#TV
#1.Mean=147.04
#2.Std=85.85
#3.Max=296.40
#4.Min=0.70

#radio
#1.Mean=23.26
#2.Std=14.85
#3.Max=49.60
#4.Min=0.0

#newspaper
#1.Mean=30.55
#2.Std=21.78
#3.Max=114
#4.Min=0.30

#Outcome: This comes under binary categorical data.So describe shows valid outcome TV is Best distribution Channel.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   radio       200 non-null    float64
#  3   newspaper   200 non-null    float64
#  4   sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
#From the above code we can have the columns datatype and memory used by the dataframe.

# %% [markdown]
# # Outliers Checking:

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
collist=df.columns.values
nrows=20
ncol=9

# %%
collist
# Out:
# array(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype=object)

# %%
range(0,5)
# Out:
# range(0, 5)

# %%
len(list(range(0,5)))
# Out:
# 5

# %%
for i in range(0, len(collist)):
    print(collist[i])
    i=i+1
    break
# Out:
# Unnamed: 0
